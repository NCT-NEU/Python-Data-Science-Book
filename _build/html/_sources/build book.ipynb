# %%
# !jupyter-book build .
# Out:
# Running Jupyter-Book v1.0.4.post1
# Source Folder: D:\Sach Khoa hoc du lieu trong Kinh te va Kinh doanh\python
# Config Path: D:\Sach Khoa hoc du lieu trong Kinh te va Kinh doanh\python\_config.yml
# Output Path: D:\Sach Khoa hoc du lieu trong Kinh te va Kinh doanh\python\_build\html
#
# ...
#
# [Warning] The `html.google_analytics_id` configuration value has moved to `html.analytics.google_analytics_id`
#
# ...
#
# Running Sphinx v7.4.7
# loading translations [en]... done
# making output directory... done
# [etoc] Changing master_doc to 'README'
# ...
